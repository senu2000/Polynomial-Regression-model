# %% [markdown]
# <a href="https://colab.research.google.com/github/senu2000/Polynomial-Regression-model/blob/main/Polinomial_regression_models_to_predict_salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/position_salaries.csv')

# %%
df.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
df = df.drop('Position', axis=1)

# %%
df.head()
# Out:
#    Level  Salary
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
x = df.drop('Salary', axis=1)
y = df['Salary']

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x, y)

print("model.coef: ", model.coef_)
print("model.intercept: ", model.intercept_)

print("Degree 1 - Training error: ", model.score(x,y))
# Out:
# model.coef:  [80878.78787879]
# model.intercept:  -195333.33333333337
# Degree 1 - Training error:  0.6690412331929895

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

model.fit(x_poly, y)

print("Degree 2 - Training error: ", model.score(x_poly,y))
# Out:
# Degree 2 - Training error:  0.9162082221443942

# %%
poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(x)

model.fit(x_poly, y)

print("Degree 3 - Training error: ", model.score(x_poly,y))
# Out:
# Degree 3 - Training error:  0.9812097727913366

# %%
poly = PolynomialFeatures(degree=4)
x_poly = poly.fit_transform(x)

model.fit(x_poly, y)

print("Degree 4 - Training error: ", model.score(x_poly,y))
# Out:
# Degree 4 - Training error:  0.9973922891706614
